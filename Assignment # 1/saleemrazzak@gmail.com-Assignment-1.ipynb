# %%
print ('''Twinkle,twinkle,little star,
       \t How i Wonder what are you!
         \t\t Up Above the world so high,
         \t\t Like a Diamond in the sky.
    Twinkle,twinkle,little star,
       \t How I wonder What are you
       ''');
# Out:
# Twinkle,twinkle,little star,
#        	 How i Wonder what are you!
#          		 Up Above the world so high,
#          		 Like a Diamond in the sky.
#     Twinkle,twinkle,little star,
#        	 How I wonder What are you

# %%
from platform import python_version

print(python_version());
# Out:
# 3.6.13

# %%
from datetime import datetime
today = datetime.now();
print("Current Date and Time = ", today);
# Out:
# Current Date and Time =  2022-01-03 18:40:31.280970

# %%
PI = 3.14;
radius = float(input(' Please Enter the radius of a circle: '));
area = PI * radius ** 2;
print('radius:',radius);
print(" Area Of a Circle = %.2f" %area);
# Out:
#  Please Enter the radius of a circle: 5
# radius: 5.0
#  Area Of a Circle = 78.50

# %%
fname = input("Input your First Name : ");
lname = input("Input your Last Name : ");
print (fname + " " + lname);
# Out:
# Input your First Name : Saleem Razzak
# Input your Last Name : Qureshi
# Saleem Razzak Qureshi

# %%
x = int(input("Enter First Value"));
y = int(input("Enter First Value"));

z = x + y;
print(z);
# Out:
# Enter First Value2
# Enter First Value4
# 6
